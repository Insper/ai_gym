# %%
from aigyminsper.search.SearchAlgorithms import BuscaLargura
from aigyminsper.search.SearchAlgorithms import BuscaProfundidade
from aigyminsper.search.SearchAlgorithms import BuscaProfundidadeIterativa
from aigyminsper.search.Graph import State
from datetime import datetime
import pandas as pd

# %%
df = pd.DataFrame(columns=['Algoritmo', 'Objetivo', 'Tempo de processamento'])
df
# Out:
# Empty DataFrame
# Columns: [Algoritmo, Objetivo, Tempo de processamento]
# Index: []

# %%
# Busca em Largura

from aigyminsper.search.SearchAlgorithms import BuscaLargura
from aigyminsper.search.SearchAlgorithms import BuscaProfundidade
from aigyminsper.search.SearchAlgorithms import BuscaProfundidadeIterativa
from aigyminsper.search.Graph import State
from datetime import datetime

class SumOne(State):

    def __init__(self, n, op, g):
        self.operator = op
        self.number = n
        self.goal = g

    def sucessors(self):
        sucessors = []
        if self.number < self.goal:
            sucessors.append(SumOne(self.number+1, "+1 ", self.goal))
            sucessors.append(SumOne(self.number+2, "+2 ", self.goal))
        return sucessors

    def is_goal(self):
        if self.goal == self.number:
            return True
        return False

    def description(self):
        return "Este é um agente simples que sabe somar 1 e 2"

    def cost(self):
        return 1

    def env(self):
        return self.number
    
def main():
    # criar um DataFrame para armazenar os resultados
    df = pd.DataFrame(columns=['Algoritmo', 'Objetivo', 'Tempo de processamento'])

    # definir os valores iniciais
    start = 1
    end = 50

    for objetivo in range(start, end+1):
        print(f'Buscando objetivo: {objetivo}')
        state = SumOne(1, '', objetivo)
        algorithm = BuscaLargura()
        start_time = datetime.now()
        result = algorithm.search(state)
        end_time = datetime.now()
        print(f'Tempo de processamento = {end_time - start_time}')
        if result != None:
            print('Achou!')
            print(result.show_path())
        else:
            print('Nao achou solucao')

        # colocar os resultados no df
        df.loc[len(df)] = ['Busca em Largura', objetivo, end_time - start_time]

    print(df)

if __name__ == '__main__':
    main()
# Out:
# Buscando objetivo: 1
# Tempo de processamento = 0:00:00
# Achou!
#
# Buscando objetivo: 2
# Tempo de processamento = 0:00:00
# Achou!
#  ; +1
# Buscando objetivo: 3
# Tempo de processamento = 0:00:00
# Achou!
#  ; +2
# Buscando objetivo: 4
# Tempo de processamento = 0:00:00
# Achou!
#  ; +1  ; +2
# Buscando objetivo: 5
# Tempo de processamento = 0:00:00
# Achou!
#  ; +2  ; +2
# Buscando objetivo: 6
# Tempo de processamento = 0:00:00
# Achou!
#  ; +1  ; +2  ; +2
# Buscando objetivo: 7
# Tempo de processamento = 0:00:00
# Achou!
#  ; +2  ; +2  ; +2
# Buscando objetivo: 8
# Tempo de processamento = 0:00:00
# Achou!
#  ; +1  ; +2  ; +2  ; +2
# Buscando objetivo: 9
# Tempo de processamento = 0:00:00
# Achou!
#  ; +2  ; +2  ; +2  ; +2
# Buscando objetivo: 10
# Tempo de processamento = 0:00:00
# Achou!
#  ; +1  ; +2  ; +2  ; +2  ; +2
# Buscando objetivo: 11
# Tempo de processamento = 0:00:00
# Achou!
#  ; +2  ; +2  ; +2  ; +2  ; +2
# Buscando objetivo: 12
# Tempo de processamento = 0:00:00
# Achou!
#  ; +1  ; +2  ; +2  ; +2  ; +2  ; +2
# Buscando objetivo: 13
# Tempo de processamento = 0:00:00
# Achou!
#  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2
# Buscando objetivo: 14
# Tempo de processamento = 0:00:00.001000
# Achou!
#  ; +1  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2
# Buscando objetivo: 15
# Tempo de processamento = 0:00:00.001000
# Achou!
#  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2
# Buscando objetivo: 16
# Tempo de processamento = 0:00:00.001000
# Achou!
#  ; +1  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2
# Buscando objetivo: 17
# Tempo de processamento = 0:00:00.001000
# Achou!
#  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2
# Buscando objetivo: 18
# Tempo de processamento = 0:00:00
# Achou!
#  ; +1  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2
# Buscando objetivo: 19
# Tempo de processamento = 0:00:00.001000
# Achou!
#  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2
# Buscando objetivo: 20
# Tempo de processamento = 0:00:00.067015
# Achou!
#  ; +1  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2
# Buscando objetivo: 21
# Tempo de processamento = 0:00:00.003001
# Achou!
#  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2
# Buscando objetivo: 22
# Tempo de processamento = 0:00:00.004000
# Achou!
#  ; +1  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2
# Buscando objetivo: 23
# Tempo de processamento = 0:00:00.005001
# Achou!
#  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2
# Buscando objetivo: 24
# Tempo de processamento = 0:00:00.008002
# Achou!
#  ; +1  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2
# Buscando objetivo: 25
# Tempo de processamento = 0:00:00.069015
# Achou!
#  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2
# Buscando objetivo: 26
# Tempo de processamento = 0:00:00.016987
# Achou!
#  ; +1  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2
# Buscando objetivo: 27
# Tempo de processamento = 0:00:00.078017
# Achou!
#  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2
# Buscando objetivo: 28
# Tempo de processamento = 0:00:00.094617
# Achou!
#  ; +1  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2
# Buscando objetivo: 29
# Tempo de processamento = 0:00:00.099024
# Achou!
#  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2
# Buscando objetivo: 30
# Tempo de processamento = 0:00:00.182043
# Achou!
#  ; +1  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2
# Buscando objetivo: 31
# Tempo de processamento = 0:00:00.275582
# Achou!
#  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2
# Buscando objetivo: 32
# Tempo de processamento = 0:00:00.481171
# Achou!
#  ; +1  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2
# Buscando objetivo: 33
# Tempo de processamento = 0:00:00.561693
# Achou!
#  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2
# Buscando objetivo: 34
# Tempo de processamento = 0:00:00.782696
# Achou!
#  ; +1  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2
# Buscando objetivo: 35
# Tempo de processamento = 0:00:01.146112
# Achou!
#  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2
# Buscando objetivo: 36
# Tempo de processamento = 0:00:01.817950
# Achou!
#  ; +1  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2
# Buscando objetivo: 37
# Tempo de processamento = 0:00:02.022126
# Achou!
#  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2
# Buscando objetivo: 38
# Tempo de processamento = 0:00:03.232315
# Achou!
#  ; +1  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2
# Buscando objetivo: 39
# Tempo de processamento = 0:00:04.820576
# Achou!
#  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2
# Buscando objetivo: 40
# Tempo de processamento = 0:00:07.094667
# Achou!
#  ; +1  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2
# Buscando objetivo: 41
# Tempo de processamento = 0:00:08.844130
# Achou!
#  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2
# Buscando objetivo: 42
# Tempo de processamento = 0:00:14.608027
# Achou!
#  ; +1  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2
# Buscando objetivo: 43
# Tempo de processamento = 0:00:17.607289
# Achou!
#  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2
# Buscando objetivo: 44
# Tempo de processamento = 0:00:25.889567
# Achou!
#  ; +1  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2
# Buscando objetivo: 45
# Tempo de processamento = 0:00:40.996547
# Achou!
#  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2
# Buscando objetivo: 46
# Tempo de processamento = 0:00:53.339332
# Achou!
#  ; +1  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2
# Buscando objetivo: 47
# Tempo de processamento = 0:01:17.374255
# Achou!
#  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2
# Buscando objetivo: 48
# Tempo de processamento = 0:01:47.417797
# Achou!
#  ; +1  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2
# Buscando objetivo: 49
# Tempo de processamento = 0:03:06.856796
# Achou!
#  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2
# Buscando objetivo: 50
# Tempo de processamento = 0:07:27.818743
# Achou!
#  ; +1  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2  ; +2
#            Algoritmo  Objetivo Tempo de processamento
# 0   Busca em Largura         1        0 days 00:00:00
# 1   Busca em Largura         2        0 days 00:00:00
# 2   Busca em Largura         3        0 days 00:00:00
# 3   Busca em Largura         4        0 days 00:00:00
# 4   Busca em Largura         5        0 days 00:00:00
# 5   Busca em Largura         6        0 days 00:00:00
# 6   Busca em Largura         7        0 days 00:00:00
# 7   Busca em Largura         8        0 days 00:00:00
# 8   Busca em Largura         9        0 days 00:00:00
# 9   Busca em Largura        10        0 days 00:00:00
# 10  Busca em Largura        11        0 days 00:00:00
# 11  Busca em Largura        12        0 days 00:00:00
# 12  Busca em Largura        13        0 days 00:00:00
# 13  Busca em Largura        14 0 days 00:00:00.001000
# 14  Busca em Largura        15 0 days 00:00:00.001000
# 15  Busca em Largura        16 0 days 00:00:00.001000
# 16  Busca em Largura        17 0 days 00:00:00.001000
# 17  Busca em Largura        18        0 days 00:00:00
# 18  Busca em Largura        19 0 days 00:00:00.001000
# 19  Busca em Largura        20 0 days 00:00:00.067015
# 20  Busca em Largura        21 0 days 00:00:00.003001
# 21  Busca em Largura        22 0 days 00:00:00.004000
# 22  Busca em Largura        23 0 days 00:00:00.005001
# 23  Busca em Largura        24 0 days 00:00:00.008002
# 24  Busca em Largura        25 0 days 00:00:00.069015
# 25  Busca em Largura        26 0 days 00:00:00.016987
# 26  Busca em Largura        27 0 days 00:00:00.078017
# 27  Busca em Largura        28 0 days 00:00:00.094617
# 28  Busca em Largura        29 0 days 00:00:00.099024
# 29  Busca em Largura        30 0 days 00:00:00.182043
# 30  Busca em Largura        31 0 days 00:00:00.275582
# 31  Busca em Largura        32 0 days 00:00:00.481171
# 32  Busca em Largura        33 0 days 00:00:00.561693
# 33  Busca em Largura        34 0 days 00:00:00.782696
# 34  Busca em Largura        35 0 days 00:00:01.146112
# 35  Busca em Largura        36 0 days 00:00:01.817950
# 36  Busca em Largura        37 0 days 00:00:02.022126
# 37  Busca em Largura        38 0 days 00:00:03.232315
# 38  Busca em Largura        39 0 days 00:00:04.820576
# 39  Busca em Largura        40 0 days 00:00:07.094667
# 40  Busca em Largura        41 0 days 00:00:08.844130
# 41  Busca em Largura        42 0 days 00:00:14.608027
# 42  Busca em Largura        43 0 days 00:00:17.607289
# 43  Busca em Largura        44 0 days 00:00:25.889567
# 44  Busca em Largura        45 0 days 00:00:40.996547
# 45  Busca em Largura        46 0 days 00:00:53.339332
# 46  Busca em Largura        47 0 days 00:01:17.374255
# 47  Busca em Largura        48 0 days 00:01:47.417797
# 48  Busca em Largura        49 0 days 00:03:06.856796
# 49  Busca em Largura        50 0 days 00:07:27.818743

# %%
df
# Out:
# Empty DataFrame
# Columns: [Algoritmo, Objetivo, Tempo de processamento]
# Index: []
